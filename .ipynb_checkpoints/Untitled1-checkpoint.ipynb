# %%
pip install mxnet

# %%
from __future__ import print_function
import os
import matplotlib as mpl
import tarfile
import matplotlib.image as mpimg
from matplotlib import pyplot as plt

import mxnet as mx
from mxnet import gluon
from mxnet import ndarray as nd
from mxnet.gluon import nn, utils
from mxnet import autograd
import numpy as np

# %%
lfw_url = 'http://vis-www.cs.umass.edu/lfw/lfw-deepfunneled.tgz'
data_path = 'lfw_dataset'
if not os.path.exists(data_path):
    os.makedirs(data_path)
    data_file = utils.download(lfw_url)
    with tarfile.open(data_file) as tar:
        tar.extractall(path=data_path)
# Out:
# Downloading lfw-deepfunneled.tgz from http://vis-www.cs.umass.edu/lfw/lfw-deepfunneled.tgz...

# %% [raw]
# epochs = 2 # Set low by default for tests, set higher when you actually run this code.
# batch_size = 64
# latent_z_size = 100
#
# ctx =  mx.cpu()
#
# lr = 0.0002
# beta1 = 0.5

# %%
target_wd = 64
target_ht = 64
img_list = []

def transform(data, target_wd, target_ht):
    # resize to target_wd * target_ht
    data = mx.image.imresize(data, target_wd, target_ht)
    # transpose from (target_wd, target_ht, 3)
    # to (3, target_wd, target_ht)
    data = nd.transpose(data, (2,0,1))
    # normalize to [-1, 1]
    data = data.astype(np.float32)/127.5 - 1
    # if image is greyscale, repeat 3 times to get RGB image.
    if data.shape[0] == 1:
        data = nd.tile(data, (3, 1, 1))
    return data.reshape((1,) + data.shape)

for path, _, fnames in os.walk(data_path):
    for fname in fnames:
        if not fname.endswith('.jpg'):
            continue
        img = os.path.join(path, fname)
        img_arr = mx.image.imread(img)
        img_arr = transform(img_arr, target_wd, target_ht)
        img_list.append(img_arr)
train_data = mx.io.NDArrayIter(data=nd.concatenate(img_list), batch_size=batch_size)

# %%
def visualize(img_arr):
    plt.imshow(((img_arr.asnumpy().transpose(1, 2, 0) + 1.0) * 127.5).astype(np.uint8))
    plt.axis('off')

for i in range(20):
    plt.subplot(4,5,i+1)
    visualize(img_list[i + 10][0])
plt.show()

# %%
#build the generator
nc = 3
ngf = 64
netG = nn.Sequential()
with netG.name_scope():
    # input is Z, going into a convolution
    netG.add(nn.Conv2DTranspose(ngf * 8, 4, 1, 0, use_bias=False))
    netG.add(nn.BatchNorm())
    netG.add(nn.Activation('relu'))
    # state size. (ngf*8) x 4 x 4
    netG.add(nn.Conv2DTranspose(ngf * 4, 4, 2, 1, use_bias=False))
    netG.add(nn.BatchNorm())
    netG.add(nn.Activation('relu'))
    # state size. (ngf*8) x 8 x 8
    netG.add(nn.Conv2DTranspose(ngf * 2, 4, 2, 1, use_bias=False))
    netG.add(nn.BatchNorm())
    netG.add(nn.Activation('relu'))
    # state size. (ngf*8) x 16 x 16
    netG.add(nn.Conv2DTranspose(ngf, 4, 2, 1, use_bias=False))
    netG.add(nn.BatchNorm())
    netG.add(nn.Activation('relu'))
    # state size. (ngf*8) x 32 x 32
    netG.add(nn.Conv2DTranspose(nc, 4, 2, 1, use_bias=False))
    netG.add(nn.Activation('tanh'))
    # state size. (nc) x 64 x 64

# build the discriminator
ndf = 64
netD = nn.Sequential()
with netD.name_scope():
    # input is (nc) x 64 x 64
    netD.add(nn.Conv2D(ndf, 4, 2, 1, use_bias=False))
    netD.add(nn.LeakyReLU(0.2))
    # state size. (ndf) x 32 x 32
    netD.add(nn.Conv2D(ndf * 2, 4, 2, 1, use_bias=False))
    netD.add(nn.BatchNorm())
    netD.add(nn.LeakyReLU(0.2))
    # state size. (ndf) x 16 x 16
    netD.add(nn.Conv2D(ndf * 4, 4, 2, 1, use_bias=False))
    netD.add(nn.BatchNorm())
    netD.add(nn.LeakyReLU(0.2))
    # state size. (ndf) x 8 x 8
    netD.add(nn.Conv2D(ndf * 8, 4, 2, 1, use_bias=False))
    netD.add(nn.BatchNorm())
    netD.add(nn.LeakyReLU(0.2))
    # state size. (ndf) x 4 x 4
    netD.add(nn.Conv2D(1, 4, 1, 0, use_bias=False))

# %%
# loss
loss = gluon.loss.SigmoidBinaryCrossEntropyLoss()

# initialize the generator and the discriminator
netG.initialize(mx.init.Normal(0.02), ctx=ctx)
netD.initialize(mx.init.Normal(0.02), ctx=ctx)

# trainer for the generator and the discriminator
trainerG = gluon.Trainer(netG.collect_params(), 'adam', {'learning_rate': lr, 'beta1': beta1})
trainerD = gluon.Trainer(netD.collect_params(), 'adam', {'learning_rate': lr, 'beta1': beta1})

# %%
from datetime import datetime
import time
import logging

real_label = nd.ones((batch_size,), ctx=ctx)
fake_label = nd.zeros((batch_size,),ctx=ctx)

def facc(label, pred):
    pred = pred.ravel()
    label = label.ravel()
    return ((pred > 0.5) == label).mean()
metric = mx.metric.CustomMetric(facc)

stamp =  datetime.now().strftime('%Y_%m_%d-%H_%M')
logging.basicConfig(level=logging.DEBUG)

for epoch in range(epochs):
    tic = time.time()
    btic = time.time()
    train_data.reset()
    iter = 0
    for batch in train_data:
        ############################
        # (1) Update D network: maximize log(D(x)) + log(1 - D(G(z)))
        ###########################
        data = batch.data[0].as_in_context(ctx)
        latent_z = mx.nd.random_normal(0, 1, shape=(batch_size, latent_z_size, 1, 1), ctx=ctx)

        with autograd.record():
            # train with real image
            output = netD(data).reshape((-1, 1))
            errD_real = loss(output, real_label)
            metric.update([real_label,], [output,])

            # train with fake image
            fake = netG(latent_z)
            output = netD(fake.detach()).reshape((-1, 1))
            errD_fake = loss(output, fake_label)
            errD = errD_real + errD_fake
            errD.backward()
            metric.update([fake_label,], [output,])

        trainerD.step(batch.data[0].shape[0])

        ############################
        # (2) Update G network: maximize log(D(G(z)))
        ###########################
        with autograd.record():
            fake = netG(latent_z)
            output = netD(fake).reshape((-1, 1))
            errG = loss(output, real_label)
            errG.backward()

        trainerG.step(batch.data[0].shape[0])

        # Print log infomation every ten batches
        if iter % 10 == 0:
            name, acc = metric.get()
            logging.info('speed: {} samples/s'.format(batch_size / (time.time() - btic)))
            logging.info('discriminator loss = %f, generator loss = %f, binary training acc = %f at iter %d epoch %d'
                     %(nd.mean(errD).asscalar(),
                       nd.mean(errG).asscalar(), acc, iter, epoch))
        iter = iter + 1
        btic = time.time()

    name, acc = metric.get()
    metric.reset()
    # logging.info('\nbinary training acc at epoch %d: %s=%f' % (epoch, name, acc))
    # logging.info('time: %f' % (time.time() - tic))

    # Visualize one generated image for each epoch
    # fake_img = fake[0]
    # visualize(fake_img)
    # plt.show()
# Out:
# INFO:root:speed: 40.71431381705884 samples/s
# INFO:root:discriminator loss = 1.746977, generator loss = 6.545331, binary training acc = 0.476562 at iter 0 epoch 0
# INFO:root:speed: 14.19920332043972 samples/s
# INFO:root:discriminator loss = 0.572097, generator loss = 13.626026, binary training acc = 0.919034 at iter 10 epoch 0
# INFO:root:speed: 14.301261024541484 samples/s
# INFO:root:discriminator loss = 0.637573, generator loss = 17.127775, binary training acc = 0.940848 at iter 20 epoch 0
# INFO:root:speed: 14.317679395788396 samples/s
# INFO:root:discriminator loss = 0.027424, generator loss = 14.791152, binary training acc = 0.939768 at iter 30 epoch 0
# INFO:root:speed: 14.367802816712944 samples/s
# INFO:root:discriminator loss = 0.178046, generator loss = 18.559633, binary training acc = 0.915777 at iter 40 epoch 0
# INFO:root:speed: 14.233096294857228 samples/s
# INFO:root:discriminator loss = 0.020734, generator loss = 7.026224, binary training acc = 0.912531 at iter 50 epoch 0
# INFO:root:speed: 14.349125193158402 samples/s
# INFO:root:discriminator loss = 3.082301, generator loss = 21.900944, binary training acc = 0.900743 at iter 60 epoch 0
# INFO:root:speed: 14.404678176044095 samples/s
# INFO:root:discriminator loss = 1.602826, generator loss = 10.615078, binary training acc = 0.889855 at iter 70 epoch 0
# INFO:root:speed: 14.452448437713088 samples/s
# INFO:root:discriminator loss = 2.021313, generator loss = 24.296991, binary training acc = 0.883198 at iter 80 epoch 0
# INFO:root:speed: 14.314551325819506 samples/s
# INFO:root:discriminator loss = 0.278252, generator loss = 4.519218, binary training acc = 0.871823 at iter 90 epoch 0
# INFO:root:speed: 14.321648521994618 samples/s
# INFO:root:discriminator loss = 0.405034, generator loss = 8.185360, binary training acc = 0.865563 at iter 100 epoch 0
# INFO:root:speed: 14.298460758812407 samples/s
# INFO:root:discriminator loss = 2.951616, generator loss = 18.731033, binary training acc = 0.856700 at iter 110 epoch 0
# INFO:root:speed: 14.340076909072415 samples/s
# INFO:root:discriminator loss = 2.216390, generator loss = 15.778789, binary training acc = 0.851821 at iter 120 epoch 0
# INFO:root:speed: 13.357207398736358 samples/s
# INFO:root:discriminator loss = 0.547503, generator loss = 5.820245, binary training acc = 0.851026 at iter 130 epoch 0
# INFO:root:speed: 14.258369059091594 samples/s
# INFO:root:discriminator loss = 0.938142, generator loss = 7.668521, binary training acc = 0.851950 at iter 140 epoch 0
# INFO:root:speed: 14.361885295259604 samples/s
# INFO:root:discriminator loss = 0.372298, generator loss = 5.286255, binary training acc = 0.854201 at iter 150 epoch 0
# INFO:root:speed: 14.401165074190807 samples/s
# INFO:root:discriminator loss = 1.032474, generator loss = 7.756304, binary training acc = 0.851854 at iter 160 epoch 0
# INFO:root:speed: 14.30516158940475 samples/s
# INFO:root:discriminator loss = 0.352291, generator loss = 2.262186, binary training acc = 0.851791 at iter 170 epoch 0
# INFO:root:speed: 14.33178756625374 samples/s
# INFO:root:discriminator loss = 0.692128, generator loss = 5.154762, binary training acc = 0.846253 at iter 180 epoch 0
# INFO:root:speed: 14.366087325282965 samples/s
# INFO:root:discriminator loss = 0.726293, generator loss = 3.455374, binary training acc = 0.843955 at iter 190 epoch 0
# INFO:root:speed: 14.433332939032063 samples/s
# INFO:root:discriminator loss = 0.513704, generator loss = 5.448606, binary training acc = 0.843905 at iter 200 epoch 0
# INFO:root:speed: 14.27194241957435 samples/s
# INFO:root:discriminator loss = 0.327916, generator loss = 4.695572, binary training acc = 0.914062 at iter 0 epoch 1
# INFO:root:speed: 14.347375049746853 samples/s
# INFO:root:discriminator loss = 0.493346, generator loss = 5.407000, binary training acc = 0.845881 at iter 10 epoch 1
# INFO:root:speed: 14.443179272836781 samples/s
# INFO:root:discriminator loss = 0.195796, generator loss = 3.374440, binary training acc = 0.853051 at iter 20 epoch 1
# INFO:root:speed: 12.966751341958787 samples/s
# INFO:root:discriminator loss = 1.139405, generator loss = 9.005050, binary training acc = 0.839718 at iter 30 epoch 1
# INFO:root:speed: 14.364301527225505 samples/s
# INFO:root:discriminator loss = 0.366718, generator loss = 6.480816, binary training acc = 0.827934 at iter 40 epoch 1
# INFO:root:speed: 14.435298181822874 samples/s
# INFO:root:discriminator loss = 0.494586, generator loss = 6.448553, binary training acc = 0.844822 at iter 50 epoch 1
# INFO:root:speed: 14.471986011254957 samples/s
# INFO:root:discriminator loss = 0.664225, generator loss = 4.266386, binary training acc = 0.852587 at iter 60 epoch 1
# INFO:root:speed: 14.298561293441923 samples/s
# INFO:root:discriminator loss = 0.697739, generator loss = 3.156286, binary training acc = 0.859265 at iter 70 epoch 1
# INFO:root:speed: 14.430943080567141 samples/s
# INFO:root:discriminator loss = 1.079477, generator loss = 8.030572, binary training acc = 0.855324 at iter 80 epoch 1
# INFO:root:speed: 14.37362131324348 samples/s
# INFO:root:discriminator loss = 0.496481, generator loss = 4.471109, binary training acc = 0.858602 at iter 90 epoch 1
# INFO:root:speed: 14.485412757880084 samples/s
# INFO:root:discriminator loss = 0.448670, generator loss = 4.673765, binary training acc = 0.863475 at iter 100 epoch 1
# INFO:root:speed: 14.344290713742073 samples/s
# INFO:root:discriminator loss = 0.551596, generator loss = 5.519738, binary training acc = 0.866061 at iter 110 epoch 1
# INFO:root:speed: 14.323400801300162 samples/s
# INFO:root:discriminator loss = 0.523212, generator loss = 5.218242, binary training acc = 0.871772 at iter 120 epoch 1
# INFO:root:speed: 14.274241189518964 samples/s
# INFO:root:discriminator loss = 0.319866, generator loss = 4.880217, binary training acc = 0.874463 at iter 130 epoch 1
# INFO:root:speed: 14.36764824421519 samples/s
# INFO:root:discriminator loss = 0.706422, generator loss = 3.665153, binary training acc = 0.873781 at iter 140 epoch 1
# INFO:root:speed: 14.27498888569818 samples/s
# INFO:root:discriminator loss = 0.490568, generator loss = 4.353106, binary training acc = 0.875983 at iter 150 epoch 1
# INFO:root:speed: 14.414172737378498 samples/s
# INFO:root:discriminator loss = 0.824036, generator loss = 6.993585, binary training acc = 0.876068 at iter 160 epoch 1
# INFO:root:speed: 14.32420334010815 samples/s
# INFO:root:discriminator loss = 0.997032, generator loss = 7.546738, binary training acc = 0.876416 at iter 170 epoch 1
# INFO:root:speed: 14.317770273023656 samples/s
# INFO:root:discriminator loss = 0.327415, generator loss = 3.124508, binary training acc = 0.873964 at iter 180 epoch 1
# INFO:root:speed: 14.188493446564122 samples/s
# INFO:root:discriminator loss = 0.586154, generator loss = 3.729077, binary training acc = 0.875205 at iter 190 epoch 1
# INFO:root:speed: 14.317157828589508 samples/s
# INFO:root:discriminator loss = 0.158506, generator loss = 4.396199, binary training acc = 0.874300 at iter 200 epoch 1

# %%
num_image = 8
for i in range(num_image):
    latent_z = mx.nd.random_normal(0, 1, shape=(1, latent_z_size, 1, 1), ctx=ctx)
    img = netG(latent_z)
    plt.subplot(2,4,i+1)
    visualize(img[0])
plt.show()
